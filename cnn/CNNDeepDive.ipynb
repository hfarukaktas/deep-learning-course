# %%
import torch
from torch import nn
import torchvision
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt

# %%
torch.manual_seed(42)

images = torch.randn(size =(32,3,32,32)) # [batch_size, color_channels, height, width]
test_image = images[0]
print(f"Image batch shape: {images.shape} [batch_size, color_channels, height, width]")
print(f"Single image shape: {test_image.shape} [color_channels, height, width]")
# Out:
# Image batch shape: torch.Size([32, 3, 32, 32]) [batch_size, color_channels, height, width]
# Single image shape: torch.Size([3, 32, 32]) [color_channels, height, width]

# %%
torch.manual_seed(42)

conv_layer = nn.Conv2d(in_channels=3, out_channels=10, kernel_size = 3, stride = 1, padding = 0)

# %%
conv_layer(test_image).shape
# Out:
# torch.Size([10, 30, 30])

# %%
test_image.shape
# Out:
# torch.Size([3, 32, 32])

# %%
x = torch.randn(1,3,32,32)
print("Input:", x.shape)

conv1 = nn.Conv2d(in_channels=3, out_channels=10, kernel_size = 3, stride = 1, padding = 1)
conv2 = nn.Conv2d(in_channels=10, out_channels=10, kernel_size = 3, stride = 1, padding = 1)
pool1 = nn.MaxPool2d(kernel_size = 2, stride = 2)

x = conv1(x)
print("After Conv1: ", x.shape)
x = conv2(x)
print("After Conv2: ", x.shape)
x = pool1(x)
print("After Pool1: ", x.shape)

conv3 = nn.Conv2d(in_channels=10, out_channels=10, kernel_size = 3, stride = 1, padding = 1)
conv4 = nn.Conv2d(in_channels=10, out_channels=10, kernel_size = 3, stride = 1, padding = 1)
pool2 = nn.MaxPool2d(kernel_size = 2, stride = 2)

x = conv3(x)
print("After Conv1: ", x.shape)
x = conv4(x)
print("After Conv2: ", x.shape)
x = pool2(x)
print("After Pool1: ", x.shape)
# Out:
# Input: torch.Size([1, 3, 32, 32])
# After Conv1:  torch.Size([1, 10, 32, 32])
# After Conv2:  torch.Size([1, 10, 32, 32])
# After Pool1:  torch.Size([1, 10, 16, 16])
# After Conv1:  torch.Size([1, 10, 16, 16])
# After Conv2:  torch.Size([1, 10, 16, 16])
# After Pool1:  torch.Size([1, 10, 8, 8])
