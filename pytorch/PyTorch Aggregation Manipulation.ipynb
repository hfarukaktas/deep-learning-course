# %%
import torch
import numpy as np

# %%
tensor1 = torch.arange(0,50,5)

# %%
tensor1
# Out:
# tensor([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45])

# %%
tensor1.min()
# Out:
# tensor(0)

# %%
tensor1.max()
# Out:
# tensor(45)

# %%
tensor1.sum()
# Out:
# tensor(225)

# %%
tensor1.median()
# Out:
# tensor(20)

# %%
# tensor1.mean() => leads to an error

tensor1 = tensor1.type(torch.float32)

# %%
tensor1.mean()
# Out:
# tensor(22.5000)

# %%
# argmax, argmin
tensor1.max()
# Out:
# tensor(45.)

# %%
tensor1.argmax()
# Out:
# tensor(9)

# %%
tensor1[9]
# Out:
# tensor(45.)

# %%
matrix = torch.tensor([[1,2,3], [4,5,6]])

# %%
matrix.shape
# Out:
# torch.Size([2, 3])

# %%
matrix.ndim
# Out:
# 2

# %%
matrix[0]
# Out:
# tensor([1, 2, 3])

# %%
matrix[0][0]
# Out:
# tensor(1)

# %%
matrix[0][0].item()
# Out:
# 1
