# %%
# !pip install torch torchvision
# Out:
# ...
#   Using cached torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (29 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 43.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [torchvision] 1/2 [torchvision]
# ...

# %%
import torch
import numpy as np

# %%
# pytorch datatypes: tensors

# %%
torch.tensor(10)
# Out:
# tensor(10)

# %%
torch.tensor([10,20])
# Out:
# tensor([10, 20])

# %%
torch.tensor([[10,20], [10,20]])
# Out:
# tensor([[10, 20],
#         [10, 20]])

# %%
scalar = torch.tensor(10)

# %%
type(scalar)
# Out:
# torch.Tensor

# %%
scalar + 5
# Out:
# tensor(15)

# %%
scalar - 10
# Out:
# tensor(0)

# %%
scalar / 2
# Out:
# tensor(5.)

# %%
scalar * 3
# Out:
# tensor(30)

# %%
scalar.dim()
# Out:
# 0

# %%
scalar.shape
# Out:
# torch.Size([])

# %%
scalar.item()
# Out:
# 10

# %%
type(scalar.item())
# Out:
# int

# %%
numpy_int = np.int32(10)

# %%
numpy_int + 10
# Out:
# np.int32(20)

# %%
numpy_int - 10
# Out:
# np.int32(0)

# %%
numpy_int * 3
# Out:
# np.int32(30)

# %%
numpy_int / 2
# Out:
# np.float64(5.0)

# %%
scalar_from_np = torch.tensor(numpy_int)

# %%
scalar_from_np.dtype
# Out:
# torch.int32

# %%
scalar.dtype
# Out:
# torch.int64

# %%
new_scalar = torch.tensor(10, dtype = torch.int16)

# %%
new_scalar
# Out:
# tensor(10, dtype=torch.int16)

# %%
tensor_float = torch.tensor(3.14)

# %%
tensor_float.dtype
# Out:
# torch.float32

# %%
tensor_float64 = torch.tensor(3.14, dtype = torch.float64)

# %%
tensor_float64
# Out:
# tensor(3.1400, dtype=torch.float64)

# %%
# vectors

# %%
vector = torch.tensor([10,20])

# %%
vector.dim()
# Out:
# 1

# %%
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
vector = torch.tensor([1,2,3])

# %%
vector.dim()
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([3])

# %%
# count # of [ => dimension
# count elements => shape

# %%
matrix = torch.tensor([[1,2],[3,4]])

# %%
matrix
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
matrix.dim()
# Out:
# 2

# %%
matrix.shape
# Out:
# torch.Size([2, 2])

# %%
tensor_example = torch.tensor([[[1,2,3],[3,4,5],[6,7,8]]])

# %%
tensor_example.dim()
# Out:
# 3

# %%
tensor_example.shape
# Out:
# torch.Size([1, 3, 3])

# %%
float_16_tensor = torch.tensor([10,20,30], dtype = torch.float16)

# %%
float_16_tensor
# Out:
# tensor([10., 20., 30.], dtype=torch.float16)
